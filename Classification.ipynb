# %% [markdown]
# # Classification

# %% [markdown]
# ## Experiment 01

# %%
import re
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import pydotplus
from IPython.display import Image 
from six import StringIO
import matplotlib.image as mpimg
#%pylab inline

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree, export_graphviz
from sklearn import preprocessing, metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, mean_squared_error

# %%
url  = "https://raw.githubusercontent.com/waldeyr/Pedro_RED_SPL/main/RED_SPL.tsv"
df = pd.read_csv(url,  sep='\t' )

# %%
df.head()
# Out:
#    Serial Region  Mutation_Position  Freq_Edition_0  Freq_Edition_1  \
# 1       1   chr1          111477647               0               0
# 2       2   chr1          111477650               0               0
# 3       3   chr1          148532070               0               0
# 4       4   chr1          148532213               0               0
# 5       5   chr1          149555537               0               0
#
#   Nucleotide_Substitution_1 Nucleotide_Substitution_2   P_Value  \
# 1                        CA                       NaN  0.000459
# 2                        GA                        GT  0.000149
# 3                        TC                       NaN  0.000056
# 4                        AG                        TC  0.000171
# 5                        AG                       NaN  0.000052
#
#    P_Value_Adjusted       Sym  ... MXE RI  SE  LogFcExp  Delta_Free_Energy  \
# 1          0.000597  C1orf162  ...   0  0   7       0.0                0.0
# 2          0.000310  C1orf162  ...   0  0   7       0.0                0.0
# 3          0.000172    NBPF14  ...   0  0   0       0.0               -0.7
# 4          0.000339    NBPF14  ...   0  0   0       0.0                0.9
# 5          0.000169    NBPF19  ...   0  0   0       0.0                0.0
#
#    Genetic_Var         Most_Severe_Cons  \
# 1          NaN    splice_region_variant
# 2          NaN  splice_acceptor_variant
# 3          NaN      3_prime_UTR_variant
# 4          NaN      3_prime_UTR_variant
# 5          NaN      3_prime_UTR_variant
#
#                                             All_Cons  AA_Change  Codons_Change
# 1  splice_region_variant splice_polypyrimidine_tr...        NaN            NaN
# 2  splice_acceptor_variant intron_variant non_cod...        NaN            NaN
# 3        downstream_gene_variant 3_prime_UTR_variant        NaN            NaN
# 4        downstream_gene_variant 3_prime_UTR_variant        NaN            NaN
# 5        3_prime_UTR_variant downstream_gene_variant        NaN            NaN
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Serial', 'Region', 'Mutation_Position', 'Freq_Edition_0',
#        'Freq_Edition_1', 'Nucleotide_Substitution_1',
#        'Nucleotide_Substitution_2', 'P_Value', 'P_Value_Adjusted', 'Sym',
#        'Ensembl_Id', 'Type', 'A3SS', 'A5SS', 'MXE', 'RI', 'SE', 'LogFcExp',
#        'Delta_Free_Energy', 'Genetic_Var', 'Most_Severe_Cons', 'All_Cons',
#        'AA_Change', 'Codons_Change'],
#       dtype='object')

# %%
def setRegion(Region):
    if Region == 'chrX': return 23 # chromossome X
    if Region == 'chrY': return 24 # chromossome Y
    if Region == 'chrM': return 25 # Mitochondrial
    return re.sub('chr', '', Region)

df['Region'] = df['Region'].apply(lambda x: setRegion(x))
# df.Nucleotide_Substitution_1 = pd.factorize(df.Nucleotide_Substitution_1, na_sentinel=None)[0]
# df.Nucleotide_Substitution_2 = pd.factorize(df.Nucleotide_Substitution_2, na_sentinel=None)[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-5de83477fb60> in <module>()
#       5     return re.sub('chr', '', Region)
#       6
# ----> 7 df['Region'] = df['Region'].apply(lambda x: setRegion(x))
#       8 # df.Nucleotide_Substitution_1 = pd.factorize(df.Nucleotide_Substitution_1, na_sentinel=None)[0]
#       9 # df.Nucleotide_Substitution_2 = pd.factorize(df.Nucleotide_Substitution_2, na_sentinel=None)[0]
#
# /home/waldeyr/.conda/envs/ml/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-105-5de83477fb60> in <lambda>(x)
#       5     return re.sub('chr', '', Region)
#       6
# ----> 7 df['Region'] = df['Region'].apply(lambda x: setRegion(x))
#       8 # df.Nucleotide_Substitution_1 = pd.factorize(df.Nucleotide_Substitution_1, na_sentinel=None)[0]
#       9 # df.Nucleotide_Substitution_2 = pd.factorize(df.Nucleotide_Substitution_2, na_sentinel=None)[0]
#
# <ipython-input-105-5de83477fb60> in setRegion(Region)
#       3     if Region == 'chrY': return 24 # chromossome Y
#       4     if Region == 'chrM': return 25 # Mitochondrial
# ----> 5     return re.sub('chr', '', Region)
#       6
#       7 df['Region'] = df['Region'].apply(lambda x: setRegion(x))
#
# /home/waldeyr/.conda/envs/ml/lib/python3.6/re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
partial_dataset = df[[
    "Region",
    "Nucleotide_Substitution_1",
     "Freq_Edition_0", 
     "Freq_Edition_1", 
     "P_Value",
    "P_Value_Adjusted",
     "Delta_Free_Energy"]]

# %%
partial_dataset
# Out:
#     Region Nucleotide_Substitution_1  Freq_Edition_0  Freq_Edition_1  \
# 1        1                        CA               0               0
# 2        1                        GA               0               0
# 3        1                        TC               0               0
# 4        1                        AG               0               0
# 5        1                        AG               0               0
# ..     ...                       ...             ...             ...
# 398     23                        TC               0               0
# 399     23                        TC               0               0
# 400     23                        TC               0               0
# 401     23                        TC               0               0
# 402     23                        TC               0               1
#
#       P_Value  P_Value_Adjusted  Delta_Free_Energy
# 1    0.000459          0.000597                0.0
# 2    0.000149          0.000310                0.0
# 3    0.000056          0.000172               -0.7
# 4    0.000171          0.000339                0.9
# 5    0.000052          0.000169                0.0
# ..        ...               ...                ...
# 398  0.000007          0.000058               -0.6
# 399  0.000224          0.000410                0.0
# 400  0.000146          0.000307                0.2
# 401  0.000005          0.000044                2.5
# 402  0.000024          0.000112                0.0
#
# [402 rows x 7 columns]

# %%
# temp.columns # test.apply(lambda x: copyRow(x), axis=1)

# %%
# Assumindo Nucleotide_Substitution_1 como etiqueta (variável dependente)
y = partial_dataset['Nucleotide_Substitution_1'].values

# %%
y
# Out:
# array(['CA', 'GA', 'TC', 'AG', 'AG', 'AG', 'AG', 'AG', 'TC', 'TC', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TA', 'TC', 'TC',
#        'CA', 'CA', 'GT', 'AG', 'CT', 'TC', 'TG', 'CG', 'TC', 'CG', 'TA',
#        'GT', 'GA', 'TC', 'TC', 'TC', 'TG', 'CT', 'CG', 'AG', 'AG', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'AG', 'AG', 'GA', 'TC',
#        'TC', 'AG', 'TC', 'AG', 'TA', 'GA', 'AG', 'GA', 'TC', 'TC', 'AG',
#        'CG', 'TG', 'GT', 'TG', 'GC', 'AG', 'AG', 'CT', 'TG', 'AG', 'TG',
#        'CT', 'TC', 'CT', 'GC', 'TG', 'CT', 'GC', 'GT', 'TC', 'AG', 'CA',
#        'CA', 'TA', 'TA', 'AG', 'TG', 'TC', 'AT', 'AG', 'TC', 'CT', 'TC',
#        'TC', 'AG', 'TC', 'AG', 'CG', 'TC', 'GT', 'CG', 'TA', 'AT', 'AG',
#        'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG',
#        'AG', 'AG', 'AG', 'AG', 'CA', 'TG', 'CT', 'CT', 'CG', 'AG', 'AG',
#        'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'CT', 'AG', 'AG', 'AG', 'AG',
#        'AG', 'CT', 'GT', 'AC', 'CA', 'TC', 'TC', 'AG', 'AG', 'GA', 'TC',
#        'GT', 'GA', 'TC', 'AG', 'AG', 'AG', 'AG', 'TC', 'TC', 'AG', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'CT', 'AG', 'AG', 'TC', 'CT', 'AG', 'TC',
#        'TC', 'AG', 'TC', 'AG', 'AG', 'CT', 'GA', 'GT', 'AC', 'TA', 'TC',
#        'TG', 'GC', 'AG', 'GA', 'TC', 'GT', 'TC', 'TC', 'TC', 'TC', 'AG',
#        'CT', 'TC', 'TC', 'TC', 'AG', 'TC', 'AG', 'AG', 'AG', 'CG', 'AT',
#        'TC', 'CG', 'CG', 'TC', 'AG', 'CT', 'TC', 'AG', 'GA', 'CG', 'GA',
#        'CT', 'GT', 'TC', 'TC', 'CT', 'TC', 'TC', 'AG', 'AG', 'TC', 'TC',
#        'TG', 'AG', 'AG', 'AG', 'TG', 'CG', 'CG', 'AG', 'AG', 'TC', 'TC',
#        'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'TC', 'AG', 'TC', 'GA',
#        'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'AG',
#        'AG', 'AG', 'AG', 'AG', 'AG', 'AG', 'GA', 'CG', 'AG', 'AG', 'AG',
#        'AG', 'TG', 'TC', 'GA', 'AG', 'TC', 'TC', 'TC', 'TA', 'TC', 'AG',
#        'AG', 'GT', 'AG', 'CT', 'CG', 'TG', 'GA', 'TG', 'AG', 'TC', 'AC',
#        'TA', 'TC', 'AG', 'TG', 'TC', 'AG', 'AG', 'AG', 'TC', 'CG', 'CG',
#        'CG', 'AG', 'AG', 'GT', 'AT', 'AC', 'TG', 'TC', 'TC', 'TC', 'TC',
#        'TA', 'AG', 'AG', 'TC', 'TC', 'CT', 'TC', 'TC', 'TC', 'TC', 'TC',
#        'AG', 'AG', 'AG', 'GC', 'AG', 'CT', 'TC', 'TC', 'AG', 'CT', 'AG',
#        'GT', 'TC', 'AC', 'GA', 'AG', 'CT', 'AG', 'TC', 'AG', 'AG', 'AG',
#        'TG', 'TC', 'TC', 'TC', 'TC', 'TC'], dtype=object)

# %%
# Removendo a coluna etiqueta
X = partial_dataset.drop(['Nucleotide_Substitution_1'], axis=1)

# %%
X
# Out:
#     Region  Freq_Edition_0  Freq_Edition_1   P_Value  P_Value_Adjusted  \
# 1        1               0               0  0.000459          0.000597
# 2        1               0               0  0.000149          0.000310
# 3        1               0               0  0.000056          0.000172
# 4        1               0               0  0.000171          0.000339
# 5        1               0               0  0.000052          0.000169
# ..     ...             ...             ...       ...               ...
# 398     23               0               0  0.000007          0.000058
# 399     23               0               0  0.000224          0.000410
# 400     23               0               0  0.000146          0.000307
# 401     23               0               0  0.000005          0.000044
# 402     23               0               1  0.000024          0.000112
#
#      Delta_Free_Energy
# 1                  0.0
# 2                  0.0
# 3                 -0.7
# 4                  0.9
# 5                  0.0
# ..                 ...
# 398               -0.6
# 399                0.0
# 400                0.2
# 401                2.5
# 402                0.0
#
# [402 rows x 6 columns]

# %%
# Separação do dataset em treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.1, shuffle = True, random_state = 1)

# %%
# Treinamento com árvore de decisão com profundidade mínima
arvore = DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=30, random_state=0)

# %%
arvore.fit(X_treino, y_treino)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=30,
#                        random_state=0)

# %%
nome_features = X.columns
nome_classes = arvore.classes_
# %pylab inline
pylab.figure(figsize=(50,50))
dot_data = StringIO()
export_graphviz(arvore, out_file=dot_data, filled=True, feature_names=nome_features, class_names=nome_classes, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
graph.write_png("arvore.png")
Image('arvore.png')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
importances = arvore.feature_importances_
indices = np.argsort(importances)[::-1]
print("Ranking de importância das características para o modelo:")
print("\n")
cont=0
for name in nome_features:
    print(f"{cont}: {name}")
    cont = cont +1
print("\n")
for f in range(X.shape[1]):
    print("%d. característica %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
f, ax = plt.subplots(figsize=(11, 9))
plt.title("Ranking de importância das características para o modelo", fontsize = 20)
plt.bar(range(X.shape[1]), importances[indices],  color="#005f73",  align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X.shape[1]])
plt.ylabel("Importância", fontsize = 18)
plt.xlabel("Número da feature", fontsize = 18)
plt.show()
# Out:
# Ranking de importância das características para o modelo:
#
#
# 0: Region
# 1: Freq_Edition_0
# 2: Freq_Edition_1
# 3: P_Value
# 4: P_Value_Adjusted
# 5: Delta_Free_Energy
#
#
# 1. característica 0 (0.454653)
# 2. característica 1 (0.235366)
# 3. característica 4 (0.222929)
# 4. característica 3 (0.087052)
# 5. característica 5 (0.000000)
# 6. característica 2 (0.000000)

# %%
# Aplicando mo modelo gerado na base de testes
y_predicoes = arvore.predict(X_teste)

# Avaliação do modelo
print(f"Acurácia da árvore: {metrics.accuracy_score(y_teste, y_predicoes)}")
print(classification_report(y_teste, y_predicoes))
# Out:
# Acurácia da árvore: 0.4878048780487805
#               precision    recall  f1-score   support
#
#           AC       0.00      0.00      0.00         2
#           AG       0.44      0.80      0.57        15
#           CA       0.00      0.00      0.00         1
#           CT       0.40      0.67      0.50         3
#           GA       0.00      0.00      0.00         1
#           GC       0.00      0.00      0.00         1
#           TA       0.00      0.00      0.00         2
#           TC       0.67      0.38      0.48        16
#
#     accuracy                           0.49        41
#    macro avg       0.19      0.23      0.19        41
# weighted avg       0.45      0.49      0.43        41
# /home/waldeyr/.conda/envs/ml/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/waldeyr/.conda/envs/ml/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/waldeyr/.conda/envs/ml/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Experiment 02
#
# random forests

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_blobs
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
modelo_random_forest = RandomForestClassifier()

# %%
modelo_random_forest.fit(X, y)
# Out:
# RandomForestClassifier()

# %%
# Avaliação do modelo
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(modelo_random_forest, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
print('Acurácia: %.2f; Desvio padrão: %.2f' % (mean(n_scores), std(n_scores)))
# Out:
# /home/waldeyr/.conda/envs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/waldeyr/.conda/envs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/waldeyr/.conda/envs/ml/lib/python3.6/site-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# Acurácia: 0.46; Desvio padrão: 0.08
