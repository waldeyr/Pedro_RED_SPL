# %% [markdown]
# # Clustering algorithms

# %%
# check scikit-learn version
import sklearn
print(sklearn.__version__)
from numpy import where
from numpy import unique
from matplotlib import pyplot
# Out:
# 0.24.2

# %%
#### Creating a random Dataset
from sklearn.datasets import make_classification
X, y = make_classification(
    n_samples=1000, 
    n_features=2, 
    n_informative=2, 
    n_redundant=0, 
    n_clusters_per_class=1, 
    random_state=0
)

# %% [markdown]
# ## Basic Clustering
#
# Just showing the points of the two variables in a graph.

# %%
# create scatter plot for samples from each class
for class_value in range(2):
	# get row indexes for samples with this class
	row_ix = where(y == class_value)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## Affinity Propagation
#
# Affinity Propagation involves finding a set of exemplars that best summarize the data.

# %%
# affinity propagation clustering
from sklearn.cluster import AffinityPropagation
# define the model
model = AffinityPropagation(damping=0.9, random_state=None)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## Agglomerative Clustering
#
# Agglomerative clustering merges examples until the desired number of clusters is achieved.

# %%
from sklearn.cluster import AgglomerativeClustering
# define the model
model = AgglomerativeClustering(n_clusters=4) # four clusters in this example
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## BIRCH
#
# Balanced Iterative Reducing and Clustering using Hierarchies involves constructing a tree structure from which cluster centroids are extracted.

# %%
from sklearn.cluster import Birch
# define the model
model = Birch(threshold=0.01, n_clusters=4)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## DBSCAN
#
# Density-Based Spatial Clustering of Applications with Noise involves finding high-density areas in the domain and expanding those areas of the feature space around them as clusters.

# %%
from sklearn.cluster import DBSCAN
# define the model
model = DBSCAN(eps=0.30, min_samples=9)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## OPTICS
#
# Ordering Points To Identify the Clustering Structure) is a modified version of DBSCAN

# %%
from sklearn.cluster import OPTICS
# define the model
model = OPTICS(eps=1, min_samples=20)
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## K-Means
#
# K-Means Clustering involves assigning examples to clusters in an effort to minimize the variance within each cluster.

# %%
from sklearn.cluster import KMeans
# define the model
model = KMeans(n_clusters=4)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## Mini-Batch K-Means
#
# Mini-Batch K-Means is a modified version of k-means that makes updates to the cluster centroids using mini-batches of samples rather than the entire dataset, which can make it faster for large datasets, and perhaps more robust to statistical noise.

# %%
from sklearn.cluster import MiniBatchKMeans
# define the model
model = MiniBatchKMeans(n_clusters=4)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## Mean Shift
#
# Mean shift clustering involves finding and adapting centroids based on the density of examples in the feature space.

# %%
from sklearn.cluster import MeanShift
# define the model
model = MeanShift()
# fit model and predict clusters
yhat = model.fit_predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## Gaussian Mixture Model
#
# As its name suggests, a Gaussian mixture model summarizes a multivariate probability density function with a mixture of Gaussian probability distributions.

# %%
from sklearn.mixture import GaussianMixture
# define the model
model = GaussianMixture(n_components=4)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# ## Experiment 01
#
# 1. Handle the dataset
# 2. Converting all textual values into integer values representing their differences (unique values) or similariry (repeated values)
# 3. Use the handled dataset to cluster under distinct algorithms

# %%
import pandas as pd
import re

# %%
url  = "https://raw.githubusercontent.com/waldeyr/Pedro_RED_SPL/main/RED_SPL.tsv"
df = pd.read_csv(url,  sep='\t' )

# %%
df.sample(n=3)
# Out:
#      Serial Region  Mutation_Position  Freq_Edition_0  Freq_Edition_1  \
# 155     155  chr12           50930653               0               1
# 8         8   chr1          149555610               0               0
# 69       69   chr1          153390558              11               0
#
#     Nucleotide_Substitution_1 Nucleotide_Substitution_2       P_Value  \
# 155                        AG                       NaN  1.247412e-07
# 8                          AG                       NaN  1.332439e-05
# 69                         GT                        GA  3.184214e-04
#
#      P_Value_Adjusted      Sym  ... MXE RI  SE  LogFcExp  Delta_Free_Energy  \
# 155          0.000005  METTL7A  ...   0  0   0  0.000000                0.0
# 8            0.000078   NBPF19  ...   0  0   0  0.000000                0.0
# 69           0.000474   S100A8  ...   0  0   0  1.692107                0.0
#
#      Genetic_Var         Most_Severe_Cons  \
# 155          NaN      3_prime_UTR_variant
# ...

# %%
def setRegion(Region):
    if Region == 'chrX': return 23 # chromossome X
    if Region == 'chrY': return 24 # chromossome Y
    if Region == 'chrM': return 25 # Mitochondrial
    return re.sub('chr', '', Region)

df['Region'] = df['Region'].apply(lambda x: setRegion(x))
df.Nucleotide_Substitution_1 = pd.factorize(df.Nucleotide_Substitution_1, na_sentinel=None)[0]
df.Nucleotide_Substitution_2 = pd.factorize(df.Nucleotide_Substitution_2, na_sentinel=None)[0]

# %%
partial_dataset = df[["Region", "Mutation_Position", "Freq_Edition_0", "Freq_Edition_1", "Nucleotide_Substitution_1", "Nucleotide_Substitution_2"]]

# %%
partial_dataset.sample(n=2)
# Out:
#    Region  Mutation_Position  Freq_Edition_0  Freq_Edition_1  \
# 33      1          150732000               0               0
# 56      1          150732803               9               0
#
#     Nucleotide_Substitution_1  Nucleotide_Substitution_2
# 33                          2                         12
# 56                          2                         12

# %%
from sklearn.cluster import KMeans
X = partial_dataset.values
X
# Out:
# array([['1', 111477647, 0, 0, 0, 12],
#        ['1', 111477650, 0, 0, 1, 0],
#        ['1', 148532070, 0, 0, 2, 12],
#        ...,
#        [23, 77828226, 0, 0, 2, 2],
#        [23, 77828331, 0, 0, 2, 2],
#        [23, 77828418, 0, 1, 2, 2]], dtype=object)

# %%
from sklearn.cluster import KMeans
# define the model
model = KMeans(n_clusters=2)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
